# %% [markdown]
# ## Import modules

# %%
from aic23_model import model
# Out:
# Loading model...
# Get features...
# Loading FrameDocs: 100%|##########| 31/31 [00:00<00:00, 54.83it/s]
# Done...
# Vector database workspace: c:\Users\admin\source\repos\HCM_AI_Challenge_2024\src\vectordb\root
# 12 threads had been found...
# Load existing index...
# Done
# Loading model: Done!

# %% [markdown]
# ## DEMO

# %% [markdown]
# ### Query

# %% [markdown]
# ### Filter 1

# %%
results1 = model.search_and_visualize(
    query_text="a man in white T shirt lifting a block of brick",
    # audio_texts=["ngày"],
    topk=50,
)  
# results1.contains(keywords=[]).visualize()
# Out:
#
#         <style>
#             .image-list {
#                 display: grid;
#                 grid-template-columns: repeat(2, 1fr);
#                 grid-gap: 10px;
#                 max-height: 900px;
#                 overflow-y: scroll;
#             }
#
#             .image-item {
#                 position: relative;
#             }
#
#             .image-item img {
#                 max-width: 100%;
#                 height: auto;
#                 cursor: pointer;
#             }
#
#             .image-item a {
#                 display: none;
#                 position: absolute;
#                 top: 0;
#                 left: 0;
#                 width: 100%;
#                 height: 100%;
#                 background-color: rgba(0, 0, 0, 0.7);
#                 text-align: center;
#                 justify-content: center;
#                 align-items: center;
#                 text-decoration: none;
#                 color: white;
#             }
#
#             .image-item:hover a {
#                 display: flex;
#             }
#         </style>
#
#        <div class="image-list">
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V001\0082.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V001 - 9412 - 6'16.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/1yHly8dYhIQ target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V015\0070.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V015 - 7555 - 5'2.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/6sbnomwKswM target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V019\0006.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V019 - 444 - 0'17.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/dKJyMk9tagc target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V019\0020.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V019 - 1687 - 1'7.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/dKJyMk9tagc target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V021\0078.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V021 - 6873 - 4'34.9</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/95ArxEjjS_U target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V001\0121.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V001 - 14013 - 9'20.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/1yHly8dYhIQ target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V025\0141.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V025 - 15012 - 10'0.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/k5TQJu8Of9s target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V019\0065.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V019 - 6138 - 4'5.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/dKJyMk9tagc target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V001\0195.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V001 - 22409 - 14'56.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/1yHly8dYhIQ target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V003\0117.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V003 - 12018 - 8'0.7</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/aa8SKMkhKGE target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V026\0007.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V026 - 495 - 0'19.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/245bAAq4j3g target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V024\0040.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V024 - 3754 - 2'30.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/GX4DkXgf_wU target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V017\0026.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V017 - 2772 - 1'50.9</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/NvNqhtsPiKM target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V023\0104.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V023 - 10689 - 7'7.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/lQVhp63kaL0 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V003\0102.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V003 - 10261 - 6'50.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/aa8SKMkhKGE target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V026\0204.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V026 - 22035 - 14'41.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/245bAAq4j3g target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V006\0054.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V006 - 5045 - 3'21.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/kRV-DvUoS_o target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V007\0069.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V007 - 6544 - 4'21.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/7BQ3878jSmM target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V001\0113.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V001 - 13194 - 8'47.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/1yHly8dYhIQ target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V015\0067.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V015 - 7288 - 4'51.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/6sbnomwKswM target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L01_V007\0054.jpg" alt="Ảnh 1">
#                 <figcaption>L01_V007 - 5053 - 3'22.1</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/7BQ3878jSmM target="_blank">Xem chi tiết</a>
#             </div>

# %%
model.root.workspace
# Out:
# 'c:\\Users\\admin\\source\\repos\\HCM_AI_Challenge_2024\\src\\vectordb\\root'

# %%
print(results1.to_json())

# %%
results1 = model.search_in_sequence_and_visualize(
    query_text_1="device on green surface",
    query_text_2="a mobile phone on hands",
    audio_texts=[],
    topk=200,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 results1 = model.search_in_sequence_and_visualize(
#       2     query_text_1="device on green surface",
#       3     query_text_2="a mobile phone on hands",
#       4     audio_texts=[],
#       5     topk=200,
#       6 )
#
# File c:\Users\admin\source\repos\HCM_AI_Challenge_2023\src\aic23_model.py:101, in AIC23_Model.search_in_sequence_and_visualize(self, query_text_1, query_text_2, strict_order, audio_texts, topk)
#      93 def search_in_sequence_and_visualize(
#      94     self,
#      95     query_text_1: str,
#    (...)
#      99     topk=1000,
#     100 ) -> FrameDocs:
# --> 101     frameDocs = self.search_in_sequence(
#     102         query_text_1=query_text_1,
#     103         query_text_2=query_text_2,
#     104         strict_order=strict_order,
#     105         audio_texts=audio_texts,
#     106         topk=topk,
#     107     )
#     108     frameDocs.visualize()
#     109     return frameDocs
#
# File c:\Users\admin\source\repos\HCM_AI_Challenge_2023\src\aic23_model.py:65, in AIC23_Model.search_in_sequence(self, query_text_1, query_text_2, strict_order, audio_texts, topk)
#      57 def search_in_sequence(
#      58     self,
#      59     query_text_1: str,
#    (...)
#      63     topk=1000,
#      64 ) -> FrameDocs:
# ---> 65     frameDocs_1 = self.search(
#      66         query_text=query_text_1, audio_texts=audio_texts, topk=topk
#      67     )
#      68     frameDocs_2 = self.search(
#      69         query_text=query_text_2, audio_texts=audio_texts, topk=topk
#      70     )
#      72     results = []
#
# File c:\Users\admin\source\repos\HCM_AI_Challenge_2023\src\aic23_model.py:44, in AIC23_Model.search(self, query_text, audio_texts, topk)
#      43 def search(self, query_text: str, audio_texts=None, topk=1000) -> FrameDocs:
# ---> 44     return self.root.search(query_text=query_text, topk=topk).contains(
#      45         keywords=audio_texts
#      46     )
#
# File c:\Users\admin\source\repos\HCM_AI_Challenge_2023\src\vector_database.py:102, in VectorDB.search(self, query_text, topk)
#      99 def search(self, query_text: str, topk=100) -> FrameDocs:
#     100     query_doc = FrameDoc(embedding=self.text_embedding(query_text))
#     101     return FrameDocs(
# --> 102         self.DB.search(inputs=DocList[FrameDoc]([query_doc]), limit=topk)[0].matches
#     103     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\vectordb\utils\sort_matches_by_score.py:24, in sort_matches_by_scores.<locals>.wrapper(*args, **kwargs)
#      21 sorted_pairs = sorted(pairs, key=lambda x: x[0], reverse=obj.reverse_score_order)
#      23 # Separate the sorted pairs into separate lists
# ---> 24 sorted_scores, sorted_matches = zip(*sorted_pairs)
#      25 doc.matches = sorted_matches
#      26 doc.scores = sorted_scores
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
model.create_temp_db(audio_texts=[" răng"])
# Out:
# Index temporary database...
# Temporary database size: 25578
#
# Done

# %%
res = model.search_temp_and_visualize("a man in white T shirt lifting a block of brick")
# Out:
#
#         <style>
#             .image-list {
#                 display: grid;
#                 grid-template-columns: repeat(2, 1fr);
#                 grid-gap: 10px;
#                 max-height: 900px;
#                 overflow-y: scroll;
#             }
#
#             .image-item {
#                 position: relative;
#             }
#
#             .image-item img {
#                 max-width: 100%;
#                 height: auto;
#                 cursor: pointer;
#             }
#
#             .image-item a {
#                 display: none;
#                 position: absolute;
#                 top: 0;
#                 left: 0;
#                 width: 100%;
#                 height: 100%;
#                 background-color: rgba(0, 0, 0, 0.7);
#                 text-align: center;
#                 justify-content: center;
#                 align-items: center;
#                 text-decoration: none;
#                 color: white;
#             }
#
#             .image-item:hover a {
#                 display: flex;
#             }
#         </style>
#
#        <div class="image-list">
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L02_V017\0068.jpg" alt="Ảnh 1">
#                 <figcaption>L02_V017 - 7081 - 4'43.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/UB-2wyspy5o target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L02_V017\0069.jpg" alt="Ảnh 1">
#                 <figcaption>L02_V017 - 7256 - 4'50.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/UB-2wyspy5o target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L06_V006\0283.jpg" alt="Ảnh 1">
#                 <figcaption>L06_V006 - 30347 - 20'13.9</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/-mNKnr37k7U target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L15_V003\0105.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V003 - 10501 - 7'0.0</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/m50KM_kcrzE target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L02_V017\0070.jpg" alt="Ảnh 1">
#                 <figcaption>L02_V017 - 7356 - 4'54.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/UB-2wyspy5o target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L20_V051\0303.jpg" alt="Ảnh 1">
#                 <figcaption>L20_V051 - 23920 - 15'56.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/vxayRoAWa_w target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L20_V051\0310.jpg" alt="Ảnh 1">
#                 <figcaption>L20_V051 - 24320 - 16'12.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/vxayRoAWa_w target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L09_V004\0084.jpg" alt="Ảnh 1">
#                 <figcaption>L09_V004 - 7769 - 5'10.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/PeJqFSM0lyA target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L07_V020\0077.jpg" alt="Ảnh 1">
#                 <figcaption>L07_V020 - 8034 - 5'21.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/xS-ibtCN4ws target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L04_V020\0261.jpg" alt="Ảnh 1">
#                 <figcaption>L04_V020 - 17484 - 11'39.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/1a3ANmsS4RM target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L20_V051\0306.jpg" alt="Ảnh 1">
#                 <figcaption>L20_V051 - 24064 - 16'2.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/vxayRoAWa_w target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L06_V015\0113.jpg" alt="Ảnh 1">
#                 <figcaption>L06_V015 - 11851 - 7'54.0</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/LF5eauBrwQ0 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L07_V019\0213.jpg" alt="Ảnh 1">
#                 <figcaption>L07_V019 - 23744 - 15'49.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/TazdiV-r1JQ target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L16_V015\0095.jpg" alt="Ảnh 1">
#                 <figcaption>L16_V015 - 9240 - 6'9.6</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/PqXxdsD7ZqM target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L10_V008\0315.jpg" alt="Ảnh 1">
#                 <figcaption>L10_V008 - 30919 - 20'36.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/GRuDBmrAft0 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L13_V006\0032.jpg" alt="Ảnh 1">
#                 <figcaption>L13_V006 - 3105 - 2'4.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/b9PXoK-vd74 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L20_V051\0304.jpg" alt="Ảnh 1">
#                 <figcaption>L20_V051 - 23936 - 15'57.4</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/vxayRoAWa_w target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L20_V037\0177.jpg" alt="Ảnh 1">
#                 <figcaption>L20_V037 - 17697 - 11'47.9</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/T0lIIB0XSUw target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L08_V025\0185.jpg" alt="Ảnh 1">
#                 <figcaption>L08_V025 - 20156 - 13'26.2</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/Z7_zIwYP9v4 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L15_V015\0050.jpg" alt="Ảnh 1">
#                 <figcaption>L15_V015 - 5337 - 3'33.5</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/l3YUAyUzlC8 target="_blank">Xem chi tiết</a>
#             </div>
#
#             <div class="image-item">
#                 <img src="../data/keyframes/L09_V011\0101.jpg" alt="Ảnh 1">
#                 <figcaption>L09_V011 - 10844 - 7'13.8</figcaption>
#                 <a href=http://www.watchframebyframe.com/watch/yt/QIgyBVy0118 target="_blank">Xem chi tiết</a>

# %%
len(detail_keyframes)

# %%
data = []
for item in results.to_json():
    for keyframe in detail_keyframes:
        print(keyframe["f"])
        if keyframe["v"] == item["video"] and keyframe["f"] == item["frame"]:
            data.append(keyframe)

# %%
len(data)

# %%
import os
import json
from tqdm import tqdm
doc_list = []
with open("../data/detail_keyframes.json", "r") as json_file:
    detail_keyframes = json.load(json_file)
json_file.close()

# %%
for idx, keyframe in enumerate(tqdm(detail_keyframes)):
    print(keyframe)
    exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for idx, keyframe in enumerate(tqdm(detail_keyframes)):
#       2     print(keyframe)
#       3     exit()
#
# NameError: name 'tqdm' is not defined
